# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data/sonar.all-data.csv")

# %%
df.head()
# Out:
#    Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#    Freq_10  ...  Freq_52  Freq_53  Freq_54  Freq_55  Freq_56  Freq_57  \
# 0   0.2111  ...   0.0027   0.0065   0.0159   0.0072   0.0167   0.0180
# 1   0.2872  ...   0.0084   0.0089   0.0048   0.0094   0.0191   0.0140
# 2   0.6194  ...   0.0232   0.0166   0.0095   0.0180   0.0244   0.0316
# 3   0.1264  ...   0.0121   0.0036   0.0150   0.0085   0.0073   0.0050
# 4   0.4459  ...   0.0031   0.0054   0.0105   0.0110   0.0015   0.0072
#
#    Freq_58  Freq_59  Freq_60  Label
# 0   0.0084   0.0090   0.0032      R
# ...

# %%
df["Label"].value_counts()
# Out:
# Label
# M    111
# R     97
# Name: count, dtype: int64

# %%
df["Label"].nunique()
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Freq_1', 'Freq_2', 'Freq_3', 'Freq_4', 'Freq_5', 'Freq_6', 'Freq_7',
#        'Freq_8', 'Freq_9', 'Freq_10', 'Freq_11', 'Freq_12', 'Freq_13',
#        'Freq_14', 'Freq_15', 'Freq_16', 'Freq_17', 'Freq_18', 'Freq_19',
#        'Freq_20', 'Freq_21', 'Freq_22', 'Freq_23', 'Freq_24', 'Freq_25',
#        'Freq_26', 'Freq_27', 'Freq_28', 'Freq_29', 'Freq_30', 'Freq_31',
#        'Freq_32', 'Freq_33', 'Freq_34', 'Freq_35', 'Freq_36', 'Freq_37',
#        'Freq_38', 'Freq_39', 'Freq_40', 'Freq_41', 'Freq_42', 'Freq_43',
#        'Freq_44', 'Freq_45', 'Freq_46', 'Freq_47', 'Freq_48', 'Freq_49',
#        'Freq_50', 'Freq_51', 'Freq_52', 'Freq_53', 'Freq_54', 'Freq_55',
#        'Freq_56', 'Freq_57', 'Freq_58', 'Freq_59', 'Freq_60', 'Label'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Freq_1     0
# Freq_2     0
# Freq_3     0
# Freq_4     0
# Freq_5     0
#           ..
# Freq_57    0
# Freq_58    0
# Freq_59    0
# Freq_60    0
# Label      0
# Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Freq_1   208 non-null    float64
#  1   Freq_2   208 non-null    float64
#  2   Freq_3   208 non-null    float64
#  3   Freq_4   208 non-null    float64
#  4   Freq_5   208 non-null    float64
#  5   Freq_6   208 non-null    float64
#  6   Freq_7   208 non-null    float64
#  7   Freq_8   208 non-null    float64
#  8   Freq_9   208 non-null    float64
#  9   Freq_10  208 non-null    float64
#  10  Freq_11  208 non-null    float64
#  11  Freq_12  208 non-null    float64
#  12  Freq_13  208 non-null    float64
#  13  Freq_14  208 non-null    float64
#  14  Freq_15  208 non-null    float64
#  15  Freq_16  208 non-null    float64
#  16  Freq_17  208 non-null    float64
#  17  Freq_18  208 non-null    float64
#  18  Freq_19  208 non-null    float64
#  19  Freq_20  208 non-null    float64
# ...

# %%
# sns.heatmap(df.corr)
sns.heatmap(df.drop("Label",axis=1).corr())
# Out:
# <Axes: >

# %%
# df.corr(numeric_only=True)
label_values=pd.get_dummies(df["Label"],dtype="int")

# %%
label_values
# Out:
#      M  R
# 0    0  1
# 1    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 203  1  0
# 204  1  0
# 205  1  0
# 206  1  0
# 207  1  0
#
# [208 rows x 2 columns]

# %%
# df[["M","R"]]=label_values

# %%
# Out:
#    Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#    Freq_10  ...  Freq_54  Freq_55  Freq_56  Freq_57  Freq_58  Freq_59  \
# 0   0.2111  ...   0.0159   0.0072   0.0167   0.0180   0.0084   0.0090
# 1   0.2872  ...   0.0048   0.0094   0.0191   0.0140   0.0049   0.0052
# 2   0.6194  ...   0.0095   0.0180   0.0244   0.0316   0.0164   0.0095
# 3   0.1264  ...   0.0150   0.0085   0.0073   0.0050   0.0044   0.0040
# 4   0.4459  ...   0.0105   0.0110   0.0015   0.0072   0.0048   0.0107
#
#    Freq_60  Label  M  R
# 0   0.0032      R  0  1
# 1   0.0044      R  0  1
# ...

# %%
df.drop(['M','R'],axis=1)
# Out:
#      Freq_1  Freq_2  Freq_3  Freq_4  Freq_5  Freq_6  Freq_7  Freq_8  Freq_9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
# sns.scatterplot(df,x=df["Freq_1"],y=df["Freq_2"],hue="Label")
# Out:
# <Axes: xlabel='Freq_1', ylabel='Freq_2'>

# %%
X=df.drop("Label",axis=1)
y=df["Label"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %% [markdown]
# ## You can do scaling manualy but when using pipeline it performs both scaling and training

# %%
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()
# scaler.fit(X_train)
# scaled_X_train=scaler.transform(X_train)
# scaled_X_test=scaler.transform(X_test)

# %% [markdown]
# ## pipellines takes a list of tuple pairs of the operations you want it to perform

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier

scaler=StandardScaler()

knn=KNeighborsClassifier()

operations=[("scaler",scaler),("knn",knn)]

from sklearn.pipeline import Pipeline

pipe = Pipeline(operations)

# %%
k_values=range(1,20)
param_grid={'knn__n_neighbors':k_values}

# %%
from sklearn.model_selection import GridSearchCV

model =GridSearchCV(pipe,param_grid=param_grid,scoring="accuracy")

# %%
model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__n_neighbors': range(1, 20)}, scoring='accuracy')

# %%
model.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('knn', KNeighborsClassifier(n_neighbors=1))],
#  'transform_input': None,
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'knn': KNeighborsClassifier(n_neighbors=1),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'knn__algorithm': 'auto',
#  'knn__leaf_size': 30,
#  'knn__metric': 'minkowski',
#  'knn__metric_params': None,
#  'knn__n_jobs': None,
#  'knn__n_neighbors': 1,
#  'knn__p': 2,
#  'knn__weights': 'uniform'}

# %%
model.get_params()
# Out:
# {'cv': None,
#  'error_score': nan,
#  'estimator__memory': None,
#  'estimator__steps': [('scaler', StandardScaler()),
#   ('knn', KNeighborsClassifier())],
#  'estimator__transform_input': None,
#  'estimator__verbose': False,
#  'estimator__scaler': StandardScaler(),
#  'estimator__knn': KNeighborsClassifier(),
#  'estimator__scaler__copy': True,
#  'estimator__scaler__with_mean': True,
#  'estimator__scaler__with_std': True,
#  'estimator__knn__algorithm': 'auto',
#  'estimator__knn__leaf_size': 30,
#  'estimator__knn__metric': 'minkowski',
#  'estimator__knn__metric_params': None,
#  'estimator__knn__n_jobs': None,
#  'estimator__knn__n_neighbors': 5,
#  'estimator__knn__p': 2,
#  'estimator__knn__weights': 'uniform',
#  'estimator': Pipeline(steps=[('scaler', StandardScaler()), ('knn', KNeighborsClassifier())]),
#  'n_jobs': None,
#  'param_grid': {'knn__n_neighbors': range(1, 20)},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
# ...

# %%
model.cv_results_
# Out:
# {'mean_fit_time': array([0.01184874, 0.01049008, 0.01064353, 0.01205506, 0.01363006,
#         0.01013651, 0.013378  , 0.01021485, 0.01008835, 0.00989943,
#         0.01032557, 0.01000676, 0.01047664, 0.01031346, 0.0112576 ,
#         0.01038833, 0.00998502, 0.01023245, 0.01011429]),
#  'std_fit_time': array([0.00146791, 0.00046538, 0.00051937, 0.0024044 , 0.00197747,
#         0.00034793, 0.004911  , 0.00070693, 0.00036019, 0.00022393,
#         0.00041458, 0.00038608, 0.00053047, 0.00048674, 0.00240743,
#         0.00077769, 0.00055489, 0.00048147, 0.00039525]),
#  'mean_score_time': array([0.01523972, 0.01273327, 0.01327057, 0.01543741, 0.0167922 ,
#         0.01335382, 0.0152492 , 0.0133718 , 0.01281857, 0.01247916,
#         0.01348453, 0.01309996, 0.01329455, 0.01370497, 0.01334643,
#         0.01335435, 0.01292019, 0.0130157 , 0.01253839]),
#  'std_score_time': array([0.0029734 , 0.00077811, 0.00076693, 0.00228775, 0.00271512,
# ...

# %%
y_pred=model.predict(X_test)

# %%
y_pred,y_test
# Out:
# (array(['M', 'R', 'R', 'R', 'M', 'R', 'M', 'M', 'R', 'M', 'M', 'R', 'M',
#         'M', 'M', 'M', 'M', 'M', 'R', 'R', 'M'], dtype=object),
#  161    M
#  15     R
#  73     R
#  96     R
#  166    M
#  9      R
#  100    M
#  135    M
#  18     R
#  148    M
#  171    M
#  30     R
#  155    M
#  180    M
#  125    M
#  197    M
#  164    M
#  190    M
#  84     R
#  75     R
#  124    M
#  Name: Label, dtype: object)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            M       1.00      1.00      1.00        13
#            R       1.00      1.00      1.00         8
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[13,  0],
#        [ 0,  8]])
