# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("data/")

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  MS SubClass MS Zoning  \
# 0             0             0           0           20        RL
# 1             1             1           1           20        RH
# 2             2             2           2           20        RL
# 3             3             3           3           20        RL
# 4             4             4           4           60        RL
#
#    Lot Frontage  Lot Area Street Lot Shape Land Contour  ... Enclosed Porch  \
# 0         141.0     31770   Pave       IR1          Lvl  ...              0
# 1          80.0     11622   Pave       Reg          Lvl  ...              0
# 2          81.0     14267   Pave       IR1          Lvl  ...              0
# 3          93.0     11160   Pave       Reg          Lvl  ...              0
# 4          74.0     13830   Pave       IR1          Lvl  ...              0
#
#   3Ssn Porch Screen Porch Pool Area Misc Val Mo Sold Yr Sold Sale Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2925 entries, 0 to 2924
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.2     2925 non-null   int64
#  1   Unnamed: 0.1     2925 non-null   int64
#  2   Unnamed: 0       2925 non-null   int64
#  3   MS SubClass      2925 non-null   int64
#  4   MS Zoning        2925 non-null   object
#  5   Lot Frontage     2925 non-null   float64
#  6   Lot Area         2925 non-null   int64
#  7   Street           2925 non-null   object
#  8   Lot Shape        2925 non-null   object
#  9   Land Contour     2925 non-null   object
#  10  Utilities        2925 non-null   object
#  11  Lot Config       2925 non-null   object
#  12  Land Slope       2925 non-null   object
#  13  Neighborhood     2925 non-null   object
#  14  Condition 1      2925 non-null   object
#  15  Condition 2      2925 non-null   object
#  16  Bldg Type        2925 non-null   object
# ...
