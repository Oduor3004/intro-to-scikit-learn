# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data/Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ----
# ----
# ----
# ## Cross Validation with cross_val_score
#
# ----
#
# <img src="grid_search_cross_validation.png">
#
# ----

# %%
X=df.drop("sales",axis=1)

# %%
y=df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model=Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
scores
# Out:
# array([-6.82773615, -6.93824123, -8.87314549, -8.09875208, -8.11849919])

# %%
abs(scores.mean())
# Out:
# np.float64(7.7712748271872725)

# %%
model=Ridge(alpha=1)

# %%
scores=cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
abs(scores.mean())
# Out:
# np.float64(2.772968978937122)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_final_test_pred)
# Out:
# 3.8001825079875227

# %% [markdown]
# ## Cross_validate

# %%
## CREATE X and y
X=df.drop('sales',axis=1)
y=df["sales"]
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
# SCALE DATA
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate

model=Ridge(alpha=100)

# %%
scores=cross_validate(model,X_train,y_train,
                      scoring=['neg_mean_squared_error',
                              'neg_mean_absolute_error'],cv=10)

# %%
scores=pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.002807    0.002689                    -4.721382
# 1  0.002146    0.001607                    -8.131560
# 2  0.001744    0.001558                    -5.430813
# 3  0.001477    0.001649                    -6.612950
# 4  0.001622    0.001374                    -9.128764
# 5  0.001464    0.001422                    -6.554434
# 6  0.002465    0.001650                    -2.893365
# 7  0.002154    0.001070                   -12.058364
# 8  0.001205    0.001053                   -12.818306
# 9  0.001554    0.001189                    -2.587867
#
#    test_neg_mean_absolute_error
# 0                     -1.722421
# 1                     -2.099793
# 2                     -1.882343
# 3                     -2.065729
# 4                     -2.492847
# 5                     -2.158478
# 6                     -1.444877
# 7                     -2.818786
# 8                     -2.419345
# 9                     -1.234893

# %%
model=Ridge(alpha=1)

# %%
scores=cross_validate(model,X_train,y_train,
                      scoring=['neg_mean_squared_error',
                              'neg_mean_absolute_error'],cv=10)

# %%
scores=pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.002109    0.001626                    -2.911867
# 1  0.001642    0.001567                    -2.784154
# 2  0.001579    0.001535                    -1.098295
# 3  0.001568    0.001680                    -1.812891
# 4  0.002775    0.002121                    -2.308968
# 5  0.002553    0.002097                    -2.051892
# 6  0.002259    0.001263                    -2.431973
# 7  0.001420    0.001119                    -2.229323
# 8  0.001262    0.001868                    -8.569988
# 9  0.001998    0.001432                    -1.432624
#
#    test_neg_mean_absolute_error
# 0                     -1.331710
# 1                     -1.269023
# 2                     -0.876497
# 3                     -1.113152
# 4                     -1.257662
# 5                     -1.067477
# 6                     -1.304290
# 7                     -1.376223
# 8                     -1.760545
# 9                     -0.847836

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_pred=model.predict(X_test)

# %%
mean_squared_error(y_test,y_final_pred)
# Out:
# 3.8001825079875227
